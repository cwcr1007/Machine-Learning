# %%
from mlxtend.plotting import heatmap
import numpy as np

# %%
a = np.zeros((2,2))
a[0:] = [0.9979,0.9964]
a[1:] = [0.9971,0.9960]
a
# Out:
# array([[0.9979, 0.9964],
#        [0.9971, 0.996 ]])

# %%
heatmap(a,
       cell_fmt='.4f')
# Out:
# (<Figure size 432x288 with 2 Axes>, <AxesSubplot:>)
